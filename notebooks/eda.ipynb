# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("D:\\Downloads\\archive\\ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
df.to_csv('D:\\Obesity_Pred\\notebooks\\data\\ObesityDataSet.csv')

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %%
df.sample(5)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 251     Male  20.000000  1.670000   78.000000                            yes
# 661   Female  20.244359  1.559186   41.952805                             no
# 1117    Male  25.035915  1.763101   88.532032                            yes
# 670     Male  18.068767  1.787787   52.000000                            yes
# 1554    Male  21.963787  1.849601  122.333425                            yes
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 251    no  2.000000  1.000000   Sometimes    no  3.000000  no  0.000000
# 661   yes  2.619835  1.000000  Frequently    no  1.198883  no  0.000000
# 1117  yes  1.973499  1.081805   Sometimes    no  2.000000  no  0.000000
# 670   yes  3.000000  3.000000   Sometimes    no  2.000000  no  0.854337
# 1554  yes  3.000000  2.218285   Sometimes    no  1.340117  no  0.428259
#
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
cat_columns = df.columns[df.dtypes == 'object']
cat_columns
# Out:
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
num_columns = df.columns[df.dtypes != 'object']
num_columns
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')

# %%
def bar_plot(df):
    for col in df[cat_columns]:
        plt.bar(df[col], df['Age'])
        plt.xlabel(col)
        plt.ylabel('Age')
        plt.title(f'{col} vs Age Bar Plot')
        plt.show()

# %%
bar_plot(df)

# %%
def count_plot(df, cat_columns):
    for col in cat_columns:
        sns.countplot(x = col, data = df)
        plt.title(f"Countplot of {col}")
        plt.xticks(rotation = 45)
        plt.show()

# %%
count_plot(df, cat_columns)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
cat_columns
# Out:
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
def wordcloud(df, cat_columns):
    for col in cat_columns:
        text = " ".join(str(i) for i in df[col])
        stopwords = set(STOPWORDS)
        wordcloud = WordCloud(stopwords = stopwords, background_color="black").generate(text)
        plt.style.use('classic')
        plt.figure(figsize=(12,10))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(f"Wordcloud of {col}")
        plt.tight_layout()
        plt.show()

# %%
wordcloud(df, cat_columns)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
def pie_chart(df, cat_columns):
    for col in cat_columns:
        plt.pie(df[col].value_counts(),labels=df[col].unique(), autopct = '%1.1f%%')
        plt.title(f"Pie Chart of {col}")
        plt.show()

# %%
pie_chart(df, cat_columns)

# %%
def heatmap(df, cat_columns):
    for col in cat_columns:
        sns.heatmap(data=pd.crosstab(index=df[col], columns=df[col]))
        plt.show()

# %%
heatmap(df, cat_columns)

# %%
num_columns
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')

# %%
def hist_plot(df, num_columns):
    for col in num_columns:
        plt.hist(df[col], bins = 20, edgecolor='k')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.title(f"Histogram of {col}")
        plt.show()

# %%
hist_plot(df, num_columns)

# %%
sns.pairplot(df[num_columns])
plt.title("Pair Plot")
plt.show()

# %%
correlation_matrix = df[num_columns].corr()
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
def kde_plot(df, num_columns):
    for col in num_columns:
        sns.kdeplot(df[col], shade = True)
        plt.xlabel(col)
        plt.ylabel('Density')
        plt.title(f"Density Plot of {col}")
        plt.show()

# %%
kde_plot(df, num_columns)

# %%
df_pie = df.groupby(['NObeyesdad']).sum()
df_pie.plot(kind = 'pie', y = 'Age', autopct = '%1.0f%%', explode = [0.05]*7, figsize = (10,10))
plt.legend(loc = 'best', fontsize = 10)
plt.title('Distribution Data')
plt.show()
